# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
print("I am learning Python!")
print("Programming is fun")
# Out:
# hello world
# I am learning Python!
# Programming is fun

# %% [markdown]
# # Hello, I'm Wumi
# ## Hello, I'm Wumi
# ### Hello, I'm Wumi
# #### Hello, I'm Wumi
#
# My list
#
# - list one
# - list two

# %%
print("Data Science is fascinating")
# Out:
# Data Science is fascinating

# %% [markdown]
# # variable

# %%
# CLASS ACTIVITY 1
# Replacing my course and name with the variables 

student_name = "Wumi"
course_name = "Data science and AI"

print("Welcome,",student_name)
print("You are enrolled in:", course_name)
print("Wishing you the best")
# Out:
# Welcome, Wumi
# You are enrolled in: Data science and AI
# Wishing you the best

# %%
# CLASS ACTIVITY 2
# Replace "Your name" with Wumi
# Replace each "Goal X" with specific goals

Your_name = "Wumi"
Goal_1 = "Be good at coding"
Goal_2 = "Ace my tests"

print("My name is :", Your_name)
print("My goal is to excellently-", Goal_1)
print(Goal_2)
# Out:
# My name is : Wumi
# My goal is to excellently- Be good at coding
# Ace my tests

# %%
# Maths in Data Science

scores = [1, 2, 3, 4, 5]
mean = sum(scores)/len(scores)
median = scores[len(scores)//2]

print(sum(scores))
print(mean)
print("The average score is:", mean)
print("The median is", median)

for score in scores:
    print(score)
# Out:
# 15
# 3.0
# The average score is: 3.0
# The median is 3
# 1
# 2
# 3
# 4
# 5

# %%
# Text processing in Data Science like web dev

statement = "Data is life"
print("Formatted:", statement.title())
# Out:
# Formatted: Data Is Life

# %%
# Conditional Statement

file_size = 200

if file_size > 50:
    print ("file is large - compress it")
else:
    print("file is accepted")
# Out:
# file is large - compress it

# %%
file_size = 100

if file_size < 150:
    print ("file is small - increase it")
else:
    print("file is accepted")
# Out:
# file is small - increase it

# %%
shoe_price = 80000

if shoe_price < 50000:
    print ("buy")
else:
    print ("walk away")
# Out:
# walk away

# %%
# for loop
# creating a list of python uses

python_uses = ["Data Analysis", "Data Science", "Web Dev", "ML", "AI"]

print("python is used for:")
for uses in python_uses:
    print("-", uses)

print("\nTotal domains:", len(python_uses))
# Out:
# python is used for:
# - Data Analysis
# - Data Science
# - Web Dev
# - ML
# - AI
#
# Total domains: 5

# %%
#running python scripts

print("=" * 40)
print("Welcome to my first Python Script")
print("=" *40)

name = input("please enter your name:,")
age = input("please enter your age:")

print("Hello", name + "!")
print("You are", age, "years old.")
print("Welcome to Python Programming!")
# Out:
# ========================================
# Welcome to my first Python Script
# ========================================
# Hello Wumi!
# You are 21 years old.
# Welcome to Python Programming!

# %% [markdown]
# ###### Quick challenge
# ###### Make a terminal form that gets user data of students, fields are: full name, level, department and hobby
# ###### Result output should be:Welcome (name) you have been enrolled for (level) in (department)......

# %%
#Solving the quick challenge

name = input("your full name:")
level = input("your level of study")
department = input("your department:")
hobby = input("your favourite hobby:")

print("Welcome", name + "!")
print("You have been enrolled for", level, "in", department + ".")
print("We have noted that you're good at", hobby + ".")
print("Kudos")
# Out:
# Welcome wumi omo!
# You have been enrolled for 200 in mbbs.
# We have noted that you're good at reading.
# Kudos

# %%
acceptable_age = 18
student_age = int(input("Your age:"))

if student_age > 18:
    print("Welcome to school")
else:
    print("Not eligible")
# Out:
# Welcome to school

# %%
#python syntax and indentation

score = 85

if score >= 50:
    print("Result: Pass")
    print("Well done, keep it up!")
else:
    print("Assessment complete.")
# Out:
# Result: Pass
# Well done, keep it up!

# %%
score = 40

if score >= 50:
    print("Result: Pass")
    print("Well done, keep it up!")

print("Assessment complete.") 
print("Try again")
# Out:
# Assessment complete.
# Try again

# %%
age = 54
if age >= 18:
    print("You are an adult.")
    print("You can vote in elections.")
else:
    print("Age check complete.")
# Out:
# You are an adult.
# You can vote in elections.

# %%
# CLASS ACTIVITY

product_price = 250.00     # original cost of product
discount_rate = 0.15       # percentage discount on product on black friday sales
discount_amount = product_price * discount_rate  # expected amount to be paid for product on sales by multiplying the original product price by the discount rate
final_price = product_price - discount_amount         # price of product after discount has been applied

print("original price:", product_price)
print("Discount:", discount_amount)
print("Final price:", final_price)
# Out:
# original price: 250.0
# Discount: 37.5
# Final price: 212.5

# %%
# print () with sep and end parameters

#default items seperated by space
print("python", "is", "fun",)
print("python is fun")

# using custom seperator
print("2024", "01", "15", sep = "-")

#custom end parameter
print("Loading", end = "... ")
print ("complete!")

#practical use
print()
for i in range(5):
    print("\n*", end="")
# Out:
# python is fun
# python is fun
# 2024-01-15
# Loading... complete!
#
#
# *
# *
# *
# *
# *

# %%
# Activity

questions = ["what is a list", "what is an object", "what is a tuple", "what is their differences"]

for question in questions:
    print("\n" + question, end = "?")
# Out:
# what is a list?
# what is an object?
# what is a tuple?
# what is their differences?

# %%
#class activity

print("=" * 40)
print("            Walmart   ")
print("=" *40)

shelf_1 = "Bag"
price_1 = 500
shelf_2 = "Shoe"
price_2 = 300
shelf_3 = "Hair"
price_3 = 100
total = price_1 + price_2 + price_3


print(shelf_1, "=", "₦"+ str(500))
print(shelf_2, "=" , "₦" + str(300))
print (shelf_3, "=", "₦", 100)
print("Total", "=", "₦", total)
print("=" * 40)
print("Thanks for shopping!")
print("=" *40)
# Out:
# ========================================
#             Walmart
# ========================================
# Bag = ₦500
# Shoe = ₦300
# Hair = ₦ 100
# Total = ₦ 900
# ========================================
# Thanks for shopping!
# ========================================

# %%
# the input function
# Activity

name = input("Your name:")
city = input("Your city:")
color = input("Your favourite color:")

print ("Hi", name + "! from", city + ".", color, "is a beautiful color" )
# Out:
# Hi wumi! from lagos. blue is a beautiful color

# %%
#  Defining and calling a function

# Define the function — nothing runs yet
def greet():
    print("Hello, welcome to Python!")
    print("Let's write some functions.")

# Call the function — NOW it runs
greet()
greet()    # can call multiple times!

# Without a call — this function body never runs
def never_called():
    print("I will never run unless called.")

never_called()

def action():
    print("Going to the gym today!")
    # calling the function to enable run
action()
# Out:
# Hello, welcome to Python!
# Let's write some functions.
# Hello, welcome to Python!
# Let's write some functions.
# I will never run unless called.
# Going to the gym today!

# %%
# CLASS ACTIVITY 10.1a
# Define a function called print_banner() that prints:
#   ********************
#   *  Python Course   *
#   ********************
# Then call it twice.

# Your code here:
def print_banner():
    print( "*" * 20)
    print( "* " + "Python Course" + " *")
    print( "*" * 20)
print_banner()
print_banner()
# Out:
# ********************
# * Python Course *
# ********************
# ********************
# * Python Course *
# ********************

# %%
# CLASS ACTIVITY 10.1b
# Define two functions:
#   1. morning_routine() — prints 3 steps of a morning routine
#   2. evening_routine() — prints 3 steps of an evening routine
# Call each function once.

# Your code here:

def morning_routine():
    print("pray")
    print("brush")
    print("bath")
morning_routine()


def evening_routine():
    print("eat")
    print("browse")
    print("sleep")
evening_routine() 

def arithmetic():
    print("Result:", 10 * 5 + 2)
arithmetic()
# Out:
# pray
# brush
# bath
# eat
# browse
# sleep
# Result: 52

# %%
def arithmetic():
    result = 20 * 3 + 7
    print(result)
arithmetic()
# Out:
# 67

# %%
# parameter and argument

# CODE EXAMPLE 10.2a: Single parameter

# 'name' is the PARAMETER — a placeholder
def greet(name):
    print(f"Hello, {name}!")

# "Amara" and "Kofi" are ARGUMENTS — actual values
greet("Amara")    # name receives "Amara"
greet("Kofi")     # name receives "Kofi"
greet("Ama")      # same function, different data each time
# Out:
# Hello, Amara!
# Hello, Kofi!
# Hello, Ama!

# %%
def get_day(day):
    print(f"Today is {day}")

get_day("Thursday")
# Out:
# Today is Thursday

# %%
def get_birthday(month_of_year):
    print(f"My birthday is in {month_of_year}")
get_birthday("August")
# Out:
# My birthday is in August

# %%
# function to define area of a rectangle

def Area(length, breadth):
    area = length * breadth
    print(f"Area: {length} * {breadth} = {area}")
Area(2,4)
# Out:
# Area: 2 * 4 = 8

# %%
# practice practice

def area(length, breadth):
    area = length * breadth
    print(f"length: {length}")
    print(f"breadth: {breadth}")
    print(f"area: {length} * {breadth} = {area}")
area(2,4)
# Out:
# length: 2
# breadth: 4
# area: 2 * 4 = 8

# %%
# parameters and arguments

# Functions become truly powerful when they work with different data each call.

# Parameter — the placeholder name in the function definition
# Argument — the actual value passed in the call
# Order matters — arguments are matched to parameters by position
# You can have multiple parameters separated by commas

# CODE EXAMPLE 10.2a: Single parameter

# 'name' is the PARAMETER — a placeholder
def greet(name):
    print(f"Hello, {name}!")

# "Amara" and "Kofi" are ARGUMENTS — actual values
greet("Amara")    # name receives "Amara"
greet("Kofi")     # name receives "Kofi"
greet("Ama")      # same function, different data each time
# Out:
# Hello, Amara!
# Hello, Kofi!
# Hello, Ama!

# %%
# CODE EXAMPLE 10.2b: Multiple parameters

def calculate_total(price, quantity):
    total = price * quantity
    print(f"Price: {price} x Qty: {quantity} = Total: {total}")

calculate_total(25.50, 3)   # price=25.50, quantity=3
calculate_total(10.00, 5)   # price=10.00, quantity=5

# Order matters! These produce different results:
def introduce(first_name, last_name):
    print(f"My name is {first_name} {last_name}.")

introduce("Amara", "Mensah")   # correct order
introduce("Mensah", "Amara")   # reversed — still runs but wrong meaning
# Out:
# Price: 25.5 x Qty: 3 = Total: 76.5
# Price: 10.0 x Qty: 5 = Total: 50.0
# My name is Amara Mensah.
# My name is Mensah Amara.

# %%
# CLASS ACTIVITY 10.2b
# Define a function area_of_rectangle(length, width)
# that prints the area. Call it with 3 different sets of values.
# Then define area_of_triangle(base, height) and call it twice.

# Your code here:
def area_of_rectangle(length, width):
    area_of_rectangle = length * width
    print(f"length: {length}")
    print(f"breadth: {width}")
    print(f"area: {length} * {width} = {area_of_rectangle}")
area_of_rectangle(3,2)

def area_of_triangle(base, height):
    area = 0.5 * base * height
    print(f"base: {base}")
    print(f"height: {height}")
    print(f"area: 0.5 * {base} * {height} = {area}")
area_of_triangle(4, 6)
# Out:
# length: 3
# breadth: 2
# area: 3 * 2 = 6
# base: 4
# height: 6
# area: 0.5 * 4 * 6 = 12.0

# %%
# Return Values
# Some functions do something (print output). Others calculate something and give back a result.

# return sends a value back to the caller
# When Python hits return, the function stops immediately
# If there is no return, the function implicitly returns None
# Critical: use return when you need the result for further use — print() only shows output, it does not pass data

# CODE EXAMPLE 10.3a: return vs print

# With return — result can be used
def add(a, b):
    return a + b

total = add(10, 25)        # capture the returned value
print("Total:", total)     # 35
print(add(5, 3) * 2)       # 16 — used directly in expression

# Without return — returns None
def show_message():
    print("Hello!")

x = show_message()    # prints "Hello!" then x = None
print(x)              # None
# print(x * 2)        # TypeError — can't multiply None
# Out:
# Total: 35
# 16
# Hello!
# None

# %%
# CODE EXAMPLE 10.3b: return stops the function

def check_pass(score):
    if score >= 50:
        return "PASS"    # function ends here if score >= 50
    return "FAIL"        # only reaches here if score < 50

print(check_pass(75))    # PASS
print(check_pass(40))    # FAIL



    

# Returning multiple related values as a tuple
def min_max(numbers):
    return min(numbers), max(numbers)

low, high = min_max([5, 2, 8, 1, 9])
print(f"Min: {low}, Max: {high}")
# Out:
# PASS
# FAIL
# Min: 1, Max: 9

# %%
# CLASS ACTIVITY 10.3a
# Define a function called celsius_to_fahrenheit(celsius)
# Formula: F = (C * 9/5) + 32
# The function should RETURN the result (not print it).
# Then call it and print the results for 0, 25, and 100 degrees.

# Your code here:

def celsius_to_fahrenheit(celsius):
    F = (celsius * 9/5) + 32
    return F
print(celsius_to_fahrenheit(0))
print(celsius_to_fahrenheit(25))
print(celsius_to_fahrenheit(100))
# Out:
# 32.0
# 77.0
# 212.0

# %%
# CLASS ACTIVITY 10.3b
# Define a function is_even(number) that returns True if the
# number is even, False otherwise.
# Then use it in a loop to print whether each number 1-10 is even or odd.

# Your code here:

def is_even(number):
    if number %2 == 0:
        return True
    
    return False

for i in range (1,11):
        if is_even(i):
            print(i, "is even")
        else:
            print(i, "is odd")
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even

# %%
# Default Arguments
# Default arguments make some parameters optional.

# Set a default with = in the function definition
# If the caller provides a value, that value is used — otherwise the default applies
# Rule: parameters with defaults must come AFTER parameters without defaults
# Violating this rule causes a SyntaxError

# CODE EXAMPLE 10.4a: Default argument

def greet(name, greeting="Hello"):
    print(f"{greeting}, {name}!")

greet("Amara")                    # Hello, Amara! (uses default)
greet("Kofi", "Good morning")     # Good morning, Kofi! (overrides default)
greet("Ama", "Welcome back")      # Welcome back, Ama!

# Wrong order → SyntaxError (uncomment to see the error)
# def greet(greeting="Hello", name):   # SyntaxError!
#     print(f"{greeting}, {name}!")
# Out:
# Hello, Amara!
# Good morning, Kofi!
# Welcome back, Ama!

# %%
# CODE EXAMPLE 10.4b: Multiple default arguments

def create_profile(name, role="Student", active=True):
    status = "Active" if active else "Inactive"
    print(f"{name} | {role} | {status}")

create_profile("Amara")                          # uses both defaults
create_profile("Mr. Boateng", role="Teacher")    # override role only
create_profile("Kofi", "Student", False)         # override both
create_profile("Ama", active=False)              # keyword argument

def list_num(num_1, num_2, num_3):
    print(f"{num_1}, {num_2}, {num_3}")
list_num(1, num_3 =5, num_2 = 4)
# Out:
# Amara | Student | Active
# Mr. Boateng | Teacher | Active
# Kofi | Student | Inactive
# Ama | Student | Inactive
# 1, 4, 5

# %%
# CLASS ACTIVITY 10.4a
# Define a function send_message(recipient, message, urgent=False)
# If urgent is True, print: "[URGENT] To: recipient — message"
# Otherwise print: "To: recipient — message"
# Call it 3 times: once with urgent=True, twice without specifying urgent.

# Your code here:

def send_message(recipient, message, urgent=False):
   #status = f"[urgent] To: {recipient} - {message}" if urgent else f"To: {recipient} - {message}"

    if urgent:
        status = f"[urgent] To: {recipient} - {message}"
    else:
        status = f" To: {recipient} - {message}"
        
    print(status)

send_message("leo", "come home now", urgent = True)
send_message("ben", "get out")
send_message("ken", "step up")
# Out:
# [urgent] To: leo - come home now
#  To: ben - get out
#  To: ken - step up

# %%
# CLASS ACTIVITY 10.4b
# Define a function calculate_discount(price, discount_percent=10)
# that returns the final price after the discount.
# Call it: once using the default 10%, once with 25%, once with 0%.

# Your code here:

def calculate_discount(price, discount_percent = 10):
    discount = price * discount_percent/100
    final_price = price -discount
    return final_price
    
print(calculate_discount(1000, 10))
print(calculate_discount(2000, 25))
print(calculate_discount(3000, 0))


# another method of function
print(f"new price is {calculate_discount(8000, discount_percent = 10)}")
print("new price is", calculate_discount(8000, discount_percent = 20))
print(f"new price is {calculate_discount(8000,)}")
print("new price is", calculate_discount(8000, discount_percent = 20))
# Out:
# 900.0
# 1500.0
# 3000.0
# new price is 7200.0
# new price is 6400.0
# new price is 7200.0
# new price is 6400.0
