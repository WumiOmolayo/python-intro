# %% [markdown]
# ## Retrieval-Augmented Generation (RAG) AND Evaluation
# ### Using PDF and TXT files as the knowledge source

# %% [markdown]
# ### **Retrieval-Augmented Generation (RAG)**
#
# Retrieval-Augmented Generation (RAG) is a powerful approach that combines information retrieval with text generation. Instead of relying solely on a language model's internal knowledge, RAG retrieves relevant documents from an external source before generating responses. This enhances accuracy, reduces hallucinations, and provides up-to-date information.
#
# In this lesson, we will implement RAG using the **OpenAI API** for both **document embeddings** and **text generation**.
#
# We use `ChatOpenAI` and `OpenAIEmbeddings` throughout. Because Together AI also
# exposes an **OpenAI-compatible endpoint**, the exact same code runs against
# Together simply by changing the API key and the base URL. You will see how in
# the setup cell below.
#
# ---

# %% [markdown]
# ### Setting Up the Environment
#
# Before we begin, ensure you have the necessary libraries installed:

# %%
# %pip install langchain langchain-community langchain-openai chromadb pypdf scikit-learn
# Out:
# Requirement already satisfied: langchain in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-community in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-openai in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (1.6.2)
# Requirement already satisfied: chromadb in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (1.5.9)
# Requirement already satisfied: pypdf in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (6.18.1)
# Requirement already satisfied: scikit-learn in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (1.9.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain) (1.6.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.12.4)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.1)
# Requirement already satisfied: anyio in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.15.1)
# Requirement already satisfied: certifi in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-community) (2.5.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.8.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.7.0)
# Requirement already satisfied: greenlet>=1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-openai) (3.13.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from langchain-openai) (0.14.0)
# Requirement already satisfied: jiter<1,>=0.16.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: regex in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.9.10)
# Requirement already satisfied: build>=1.0.3 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (1.6.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.4)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (0.23.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (4.70.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (1.83.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (5.3.0)
# Requirement already satisfied: rich>=10.11.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from scikit-learn) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pyproject_hooks in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: cloudpickle>=3.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.2)
# Requirement already satisfied: requests-oauthlib in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.11)
# Requirement already satisfied: flatbuffers in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (7.36.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from rich>=10.11.0->chromadb) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.31.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.32.6)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.5)
# Requirement already satisfied: httptools>=0.8.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\Users\Hp\python-intro\myvenv\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Import the required libraries:**
#
# - `PyPDFLoader`: Reads a PDF file and returns one document per page.
# - `RecursiveCharacterTextSplitter`: Cuts long documents into smaller chunks.
# - `Document`: The LangChain container for a piece of text.
# - `OpenAIEmbeddings`: Embeds text into vector representations.
# - `Chroma`: Stores and retrieves embedded documents efficiently.
# - `ChatOpenAI`: Uses an AI model for text generation.
# - `ChatPromptTemplate` and `StrOutputParser`: Create structured prompts and extract responses.
# - `dotenv` :  This helps to load the environment variables like API Keys.

# %%
from langchain_chroma import Chroma
import os
import chromadb
import pathlib
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv

# %% [markdown]
# **Loading the Documents**
#
# For this tutorial, we will use two separate files as our knowledge sources:
#
# - `msme_policy.pdf` - a PDF about the National Policy on MSMEs in Nigeria.
# - `business_registration_guide.txt` - a text file about registering a business with the CAC.
#
# These are two **different** sources. We load them separately and keep them
# separate, so you can decide which one to put in the vector database.
#
# **How we read each file**
#
# - The PDF needs a special reader, because a PDF is not plain text. We use
#   `PyPDFLoader`, which returns **one document per page**.
# - The text file needs nothing special. We open it with plain Python
#   `with open(...)`, exactly the way you learned in the file handling topic.
#
# `with open(...)` is the normal way to read a file in Python. The `with` block
# closes the file automatically when it finishes, even if something goes wrong.
#
# *You can swap in your own PDF or text file later. Just change the two file names below.*

# %%
# Source 1 - the PDF. PyPDFLoader returns one document per page.

pdf_docs = PyPDFLoader("nhp_policy.pdf").load()

# Source 2 - the text file. Plain Python can read this on its own.
# with open("business_registration_guide.txt", "r", encoding="utf-8") as f:
#    txt_text = f.read()

print("Pages loaded from the PDF :", len(pdf_docs))
# print("Characters read from TXT  :", len(txt_text))

print("First 300 characters of the PDF:")
print(pdf_docs[0].page_content[:300])

# print()
# print("First 300 characters of the TXT:")
# print(txt_text[:300])
# Out:
# Pages loaded from the PDF : 97
# First 300 characters of the PDF:
# National
# Health Policy 2016
# Promoting the Health of Nigerians to Accelerate
# Socio -economic Development
#
#
#
#
#
#
#
# Federal Ministry of Health ,
# September  2016

# %% [markdown]
# **Splitting the documents into chunks**
#
# A whole PDF page or a whole text file is usually too long to embed as a single
# vector. Long text also makes retrieval less precise, because one vector has to
# represent many different ideas at once.
#
# So we cut each document into smaller overlapping **chunks**:
#
# - `chunk_size=800` - each chunk is about 800 characters.
# - `chunk_overlap=100` - each chunk repeats the last 100 characters of the one
#   before it, so a sentence is not cut in half and loses its meaning.
#
# We split the PDF and the text file **separately**, so they stay as two distinct
# sets of chunks.
#
# The splitter has two methods, and we need one of each here:
#
# - `split_documents(...)` - use this when you already have documents, like the
#   pages that came back from `PyPDFLoader`.
# - `create_documents([...])` - use this when you have **plain text strings**, like
#   the text we just read with `with open(...)`. It cuts the text up and wraps each
#   piece into a document for us.
#
# After this step both sources look the same, so the rest of the notebook does not
# care which file a chunk came from.

# %%
# The same splitter is used for both sources
splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=100
)

# The PDF pages are already documents, so we split the documents
pdf_chunks = splitter.split_documents(pdf_docs)

# The TXT is one long plain string, so we create documents from it
# txt_chunks = splitter.create_documents([txt_text])

print("Chunks from the PDF :", len(pdf_chunks))
# print("Chunks from the TXT :", len(txt_chunks))


# ---------------------------------------------------------------
# CHOOSE WHICH SOURCE TO EMBED
# Uncomment the line you want and comment out the others.
# ---------------------------------------------------------------
# chosen_chunks = pdf_chunks + txt_chunks     # use both together
# chosen_chunks = pdf_chunks                # use only the PDF
# chosen_chunks = txt_chunks                # use only the text file


# Chroma only needs the plain text of each chunk
documents = [chunk.page_content for chunk in chosen_chunks]

print()
print("Documents ready to embed:", len(documents))
# Out:
# Chunks from the PDF : 249
#
# Documents ready to embed: 256

# %% [markdown]
# `documents` is now a simple list of text strings. That is all we need to embed.
#
# **Which source answers which question?**
#
# The two files cover different ground, so the source you pick decides which
# questions the model can answer:
#
# | Question asked later in this notebook | Answered by |
# |---|---|
# | How long does a business name reservation last? | the TXT file |
# | What is the first step in setting up a business? | the TXT file |
# | How do I register a construction business? | the TXT file |
# | The five RAGAS evaluation questions (MSME classification, SMEDAN/BoI/CBN, sectors, challenges, interventions) | the PDF |
#
# That is why the default above is **both together**. If you switch to only one
# source, expect the questions belonging to the other file to return nothing
# useful - which is itself a good thing to show students about RAG.
#
# **If you change source, reset the vector store.** Either change
# `collection_name` in the Chroma cell below, or delete the `chroma_store` folder.
# Otherwise the new text is mixed in with whatever you embedded before.

# %%
#use this to comfirm the number documents to embed 
print(f"Total Documents to be embedded {len(documents)}\n")
# Out:
# Total Documents to be embedded 256

# %% [markdown]
# This loads the API keys from your `.env` file.
#
# **How the configuration works**
#
# Only the keys are secret, so only the keys live in `.env`. The base URLs and the
# model names are written out in the next cell so you can read and change them.
#
# Two servers are involved and they are not interchangeable:
#
# | | chat | embeddings |
# |---|---|---|
# | base URL | `gemma-4.publicaai.com/v1` | `qwen-embed.publicaai.com/v1` |
# | key | `OPENAI_API_KEY` | `EMBEDDING_API_KEY` |
# | model | `google/gemma-4-E4B-it` | `Qwen/Qwen3-Embedding-0.6B` |
#
# Sending a chat request to the embedding server (or the wrong key to either one)
# returns `AuthenticationError: 401 - Unauthorized`.

# %%
load_dotenv()

# ---------------------------------------------------------------
# PROVIDER CONFIG
# The API keys are secret, so they live in the .env file.
# Everything else is written out here so you can see it.
#
# NOTE: the chat model and the embedding model run on TWO DIFFERENT
# servers. Each one needs its own base URL and its own key.
# Do not mix them up.
# ---------------------------------------------------------------

# --- Chat model ---
api_key         = os.getenv("OPENAI_API_KEY")
base_url        = "https://museglimmer30b.publicaai.com/v1"
chat_model_name = "meta-models/Muse-Glimmer-30B"

# --- Embedding model (different server, different key) ---
embedding_api_key    = os.getenv("EMBEDDING_API_KEY")
embedding_base_url   = "https://qwen-embed.publicaai.com/v1"
embedding_model_name = "Qwen/Qwen3-Embedding-0.6B"

print("Chat base URL     :", base_url)
print("Chat model        :", chat_model_name)
print("Embed base URL    :", embedding_base_url)
print("Embedding model   :", embedding_model_name)
# Out:
# Chat base URL     : https://museglimmer30b.publicaai.com/v1
# Chat model        : meta-models/Muse-Glimmer-30B
# Embed base URL    : https://qwen-embed.publicaai.com/v1
# Embedding model   : Qwen/Qwen3-Embedding-0.6B

# %% [markdown]
# **Setting Up ChromaDB for embeddings Storage**
#
# chroma_dir: Gets the current working directory where the notebook is located.
#
# chroma_path: Creates a folder named chroma_store to store the vector embeddings.

# %%
chroma_path = "health_store"

# %% [markdown]
# - **We are using the `embedding_model_name` you chose above** to convert documents into vector embeddings.

# %%
# Initialize the embedding model
embeddings = OpenAIEmbeddings(
    model=embedding_model_name,
    api_key=embedding_api_key,
    base_url=embedding_base_url

)

# %% [markdown]
# - Creates a **vector database (Chroma)** for the documents.
# - Adds the **embedded texts** to the database.

# %%
# Initialize ChromaDB
healthvdb = Chroma(
    collection_name="health_policy",
    embedding_function=embeddings,
    persist_directory=chroma_path
)

# %%
# Add documents to the vector database
healthvdb.add_texts(
    texts=documents
)
# Out:
# ['a1769269-5331-4b8f-a9f3-e399ccb63d2b',
#  'e82b824d-a608-480e-881f-3e7fd81feffe',
#  '1e5a906d-0113-4bc5-be30-62fae4279c62',
#  'd9d53869-964a-4020-b05a-2b2c53fe3552',
#  'f92ae480-c717-40f6-ba76-b0ec0e7785d6',
#  'c3140d20-d519-453b-9fc6-5f67ec4836b4',
#  '0e68b0cc-e01b-4a4a-a1d7-48fd031b89a5',
#  'e15c7b01-441b-411a-b5c4-a3415f193b48',
#  '41480585-f246-49aa-b209-0e3daa65b340',
#  'b4cd8356-ae82-49ec-9dea-3a0902980491',
#  '6604ca19-2b4c-4456-9fe9-4761d9f16919',
#  '10dc9304-c591-4a22-8aad-c4eb6ae97dc8',
#  '57f906b4-bef0-4e2b-82c6-d43b1ff710e3',
#  '8733fe61-426c-4b6a-a82c-42ff70697b02',
#  '0bf603ac-44ac-411a-918b-2615e18bbb85',
#  'e9b264ec-b69c-44ab-b8a5-f19d920d8723',
#  '7511b426-247c-4c4f-850f-8d530672b744',
#  'edf89e86-460d-4b3f-bdbf-b7045c05c3b0',
#  'f5a67f6e-1543-4a56-b9c0-7fc64c592e1e',
#  '59d29d75-d7f0-4043-a2f4-4b993109d2c7',
#  '860b7869-5804-40f2-b83b-ee8a386481aa',
#  'a63016e8-0868-4eaa-803d-171eafb095ff',
#  '62fc665e-66cf-4fbe-92c6-59b7a1b5c355',
#  '0398c010-372c-44aa-ba6e-5ef445489dbd',
#  'b90d64c3-91a9-4219-86b2-9f2629f07d37',
#  '8a5f23b2-46ec-4f26-8597-eb11509f17bb',
#  'ac2f2b47-bf45-4bcf-8995-702dd644d5d3',
#  '0f87cfab-a54b-4a3d-b777-7ff3957609f6',
#  'e0fbe622-ca10-4efb-8f08-18e419e7cdc3',
#  '5440fdfc-302f-40a8-837d-11622d25b088',
#  '5613ca6c-101b-4524-a241-d6236384383f',
#  '29e41e72-dc67-4da9-a940-e79ea2ca61cd',
#  '3d3c3a60-9fab-468b-8a7c-732d4b311d10',
#  '87f27b14-71b9-49b9-906e-f1fbf372d66f',
#  'fcad381e-1a26-405d-ab59-4232da7d2088',
#  'eaf1fb90-093b-4cd7-9f88-b8e5ffd6b586',
#  'd889bbf0-2897-4c20-8d7f-40321e532cd1',
#  'da215b85-07f2-49be-8069-efeae044a45a',
#  '990f633d-94f2-4d53-898d-0fb2a78edc2f',
#  '723a4b9e-3103-429c-a610-d6e565c1eef0',
#  'c6a8e9ba-f993-405e-b637-a712157e8ebe',
#  'ae22f219-3cbe-4de3-930c-3021344ccfee',
#  '7726ceb1-5b1c-4e64-b601-cb76f44b5a13',
#  'cb726858-f044-40f0-845d-91718150ffcc',
#  'ec09ed93-5ea9-4aeb-ab9b-16067d3024de',
#  'c2a08380-9c64-4215-bf35-6200f29db107',
#  '111d2320-0134-4e1e-a7c9-4368c07831ee',
#  'b3fdd016-d1b6-4353-a92d-4b5ad847280b',
#  '90768118-7c08-401a-965a-febcc3b4edd9',
#  '931ea9b2-3c15-48a0-96c1-fdb9ad252f7a',
#  'a12ab031-2dc3-4fca-8c00-23c629604cba',
#  'a1c91dab-a2b2-4776-9d52-0b86c2d001a1',
#  'b8beaf5f-8b42-4e29-a187-9be663ffb892',
#  'c1a4b597-4f2c-4456-91d8-a20ce0914f65',
#  '013206ac-e6ba-4052-8fa7-83765a2e3369',
#  'ef2715bf-bfd9-4687-be5f-757ead6f5906',
#  'a3a86ec7-9c6c-4a81-b32f-c261978c4586',
#  '742880f1-44bf-407d-8601-dd13f701496a',
#  '2764e5fd-6ea4-4df8-b3d9-7c58912be040',
#  'd9556354-201d-4e8d-894f-e4742d2bd380',
#  '52f83175-1ff3-40fd-8d80-c97975fd508d']

# %% [markdown]
# **If this cell restarts your kernel**
#
# It is almost always one missing Microsoft file, not a mistake in your code.
#
# Chroma uses a part written in C++, and that part needs the **Visual C++
# Redistributable** from Microsoft. Many programs install it, so most computers
# already have it. That is why this cell works for some people and not others.
#
# **Fix it like this (Windows):**
#
# 1. Download it here:
#    [vc_redist.x64.exe](https://aka.ms/vs/17/release/vc_redist.x64.exe)
#    (official Microsoft link - the file is about 25 MB)
# 2. Close VS Code and Jupyter completely.
# 3. Open the file you downloaded and click **Install**.
#    If it shows **Repair** instead, click Repair - that means it is already
#    there but damaged.
# 4. When it finishes, **restart your computer**. This step matters, skipping it
#    is why it sometimes seems not to have worked.
# 5. Open the notebook again, click **Restart Kernel**, then run the cells from
#    the top.
#
# That fixes it for most students.
#
# **If it still restarts the kernel after all that**, the computer cannot run
# this part, and nothing you type will change it. Run the next cell instead and
# carry on with the lesson.
#
# The next cell does not use Chroma at all. It saves your documents into a
# `msme_store` folder, the same way Chroma saves into `chroma_store`, so you
# embed once and can deploy the folder with your app.

# %%
# Run this ONLY if the cell above restarts your kernel.
# This does not use Chroma. It saves into a folder, so you embed only once.
import os
from langchain_community.vectorstores import SKLearnVectorStore

os.makedirs("msme_store", exist_ok=True)
store_path = "msme_store/msme_index.json"

msmevdb = SKLearnVectorStore.from_texts(
    documents,
    embedding=embeddings,
    persist_path=store_path,
    serializer="json",
)
msmevdb.persist()

print("Saved", len(documents), "documents to", store_path)
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       6 os.makedirs("msme_store", exist_ok=True)
#       7 store_path = "msme_store/msme_index.json"
#       8
#       9 msmevdb = SKLearnVectorStore.from_texts(
# ---> 10     documents,
#      11     embedding=embeddings,
#      12     persist_path=store_path,
#      13     serializer="json",
#
# NameError: name 'documents' is not defined

# %% [markdown]
# Once the folder exists you never have to embed those documents again. To open
# the saved store later - after a restart, or inside the app you deploy - run
# this instead of the cell above. It loads the file from the folder, so it costs
# nothing and needs no internet for the documents themselves.

# %%
# Later, or in your deployed app: open the saved store without embedding again.
# from langchain_community.vectorstores import SKLearnVectorStore
#
# msmevdb = SKLearnVectorStore(
#     embeddings,
#     persist_path="msme_store/msme_index.json",
#     serializer="json",
# )

# %% [markdown]
# ### The Retriever
# Retrieving Documents for a Query

# %%
# Maximal Marginal Relevance (MMR) for diverse and relevant results.
health_retriever = healthvdb.as_retriever(search_type="mmr")

# %% [markdown]
# k defines the final number of documents that the retriever will return. use for concise and relevant results instead of retrieving too much data.
#
# fetch_k determines how many documents are initially retrieved before filtering.

# %%
health_retriever = healthvdb.as_retriever(search_type="mmr", search_kwargs={'k': 4, 'fetch_k': 10})

# %% [markdown]
# Retrieves related documents based on `question`

# %%
question = "What is the mission and vision of the national health policy?"
health_retriever.invoke(question)
# Out:
# [Document(id='ec09ed93-5ea9-4aeb-ab9b-16067d3024de', metadata={}, page_content='77 \n6.3Data management and feedback \nMonitoring and evaluation of progress on policy implementation shall require data collection, collation and \nanalysis on governance and leadership, the burden of diseases, health services, health financi ng, human \nresources for health, medicines, vaccines & other health technologies, health infrastructure and equipment  \nand other areas as defined in the NSHDP . The required data can be acquired through special surveys or the \nacquisition of routine data fromDHIS2.  \nFeedback on progress o f policy implementation shall be carried out through the generation and \ndissemination of periodic reports, annual review meetings at national, zonal & state levels.'),
#  Document(id='301ecc18-8709-49a7-bd9c-bfc1acee6f5a', metadata={}, page_content='55 \n\uf0b7 To establish a framework for the effective utilisation of research findings for evidence-based decision \nmaking \nPolicy Orientations/Initiatives \n\uf0b7 Ensure the implementation of the National Health Research Policy and Priorities 2014 \n\uf0b7 Facilitate the development and operational ization of a national research agenda , including \nbasic/translational research and product development , as well as health systems/policy \nimplementation research  \n\uf0b7 Facilitate adequate resource allocation for research and surveys at all levels , in line with ag reed \nInternational Declarations especially the Algiers Declaration on Health Research1 \n\uf0b7 Strengthen the national health research institutes ( the National Institute of Medical Research and'),
#  Document(id='434eccf8-03cb-442d-a0ca-ce16c50c2bf3', metadata={}, page_content='2.5.9. Health Promotion, Community Ownership and Participation \nThere are various health promotion units at both federal and state levels.  However, they often lack effective \nleadership for health promotion. According to the National Health Promotion Policy  2006, there is little \nunderstanding of the concepts of health promotion, consumer rights, the need for multi-sectoral action, and \nthe promotion of a supportive environment for behavioural changes in health care . In addition, there are \nfew frameworks and guidelines for systematic planning and management of health education \ninterventions21.  \nThere is a framework for the devel opment of, and engagement with, community structures , such as Ward'),
#  Document(id='ac2f2b47-bf45-4bcf-8995-702dd644d5d3', metadata={}, page_content='68 \nS/N Stakeholders                                     Roles and responsibilities \n\uf0b7 Shall provide technical assistance in advancing health programs \n38.  Media (Print and \nElectronic) \n\uf0b7 Shall support demand creation for health services \n\uf0b7 Shall support health promotion and awareness creation for health care \n39.  The Private Sector \uf0b7 Shall contribute to health service delivery within the national health \npolicy framework in compliance with national standards and guidelines  \n\uf0b7 Shall invest in healthcare \n\uf0b7 Shall at all times comply with the provisions of the National Health Policy \n40 Civil Society \uf0b7 Shall act as an instrument for ensuring accountability and monitoring \nhealth service provisions \n\uf0b7 Shall create demand for health services and mobilize communities in the')]

# %%
question = "What is the leading cause of maternal mortality in Nigeria?"
health_retriever.invoke(question)
# Out:
# [Document(id='70fb7236-3adb-4116-8757-b93925f77da3', metadata={}, page_content='28 \nChapter 4 :POLICY OBJECTIVES AND ORIENTATIONS \n4.1 Priority Public Health and Other Health Problems \n4.1.1. Reproductive, Maternal, Neonatal, Child and Adolescent Health \nThe Goal \nTo reduce maternal, neonatal , child and adolescent morbidity and mortality in Nigeria , and promote universal \naccess to comprehensive sexual and reproductive health services for adolescents and adults throughout their \nlife cycle \nObjectives \n\uf0b7 To reduce maternal morbidity and mortality; \n\uf0b7 To reduce childhood mortality and ensure optimal growth, protection and development for all new-\nbornsand children under-five; \n\uf0b7 To promote the healthy growth and development of school-aged children; \n\uf0b7 To improve access to adolescent health information and services and;'),
#  Document(id='a63016e8-0868-4eaa-803d-171eafb095ff', metadata={}, page_content='and outside the country \n28 State Ministries of \nInformation \nDitto \n29.  Ministry of Defence  \uf0b7 Shall h armonize the health strategies for defence staff , in line with the \nNHP \n\uf0b7 Shall be a ctively involved as participants  in the multi -sectoral forum on \nimplementing the ‘Health-in-All’ policies and mechanisms \n30. State Ministries of \nEnvironment \n\uf0b7 Shall c ollaborate with the State Ministries  of Health and other line \nministries to implement environmental management programs to reduce \nenvironmental-related health risks \n\uf0b7 Shall be a ctively involved as participants  in the multi -sectoral forum on \nimplementing the ‘Health-in-All’ policies and mechanisms \n31. NAFDAC \uf0b7 Shall conduct appropriate tests and ensure compliance with standard'),
#  Document(id='73bbf59f-cfa5-495b-80ab-01da90a73cba', metadata={}, page_content='current mortality levels, one in every 15 Nigerian children die in their first year, and one in every eight do not \nsurvive to their fifth birthday. The neonatal mortality rate, at 37 deaths per 1,000 live births, has not \ndeclined to the same extent as the infant and under-five mortality rates11. \nTwelve percent of women and men are likely to die between the ages of 15 and 50. These probabilities have \ndecreased since 2008 by 23 percent for women and 27 percent for men. Maternal deaths account for 32 \npercent of all deaths among women  in the age group 15-49. The maternal mortality ratio was 57 6 maternal \ndeaths per 100,000 live births for the seven -year period preceding the survey  reported in Table 1 . The'),
#  Document(id='26fa9553-061c-43f9-8988-16a75c5f7776', metadata={}, page_content='the maintenance of health infrastructure , equipment and transport for eligible primary care \nfacilities, in line with the National Health Act 2014 \n\uf0b7 Promote adherence to all quality requirements and standards for equipment and safety for all the \nvarious categories of health facilities \n\uf0b7 Strengthen the implementation of the issuance of, and compliance with, the Certificate of Standards \nin line with the National Health Act 2014 \n\uf0b7 Ensure the classificati on of health establishments according to the National Health Act  2014 to \nguarantee efficiency and equitable access to health services \n\uf0b7 Promote multi -sectoral and public-private partnership for infrastructural development and \nmaintenance')]

# %% [markdown]
# **Generating Responses Using Llama 3.3 70b  model**

# %% [markdown]
# - Let us re-create the chat model for response generation.
# - **`temperature= 0` ensures deterministic outputs.**
# - You can point `model` at any chat model your provider offers - just change the
#   name below, or change `chat_model_name` in the setup cell to change it everywhere.

# %%
#initialize the chatmodel
chatmodel = ChatOpenAI(
    api_key=api_key,
    base_url=base_url,
    model=chat_model_name,
    temperature=0
)

# %% [markdown]
# ### **Prompting the LLM**

# %% [markdown]
# Creates a prompt template (prompt) with a system prompt and placeholders for the context and user question

# %%
#using from template method
prompt = ChatPromptTemplate.from_template(
    """You are a Health specialist and consultant providing information and enlightment on health related topics and policy in nigeria.
You will be provided with the context: {context} to answer the user's question.
The context includes sections on health information, guidelines and policies.
Provide a comprehensive response. 

question: {question}""")

# %% [markdown]
# Initializes the chat completion chat model (llm) to use for generating responses
#
# Creates a simple output parser (parse_output) to parse the LLM output as a string
#
# Chains all the above components using LangChain’s pipe ( | ) notation to create a simple RAG workflow (rag_chain)

# %%
question = "How can communicable diseases be prevented?"

#retrieve the document
get_doc = health_retriever.invoke(question)
# Prepare the input for the chain
input = {"context": get_doc, "question": question}

# Create the chain
chain = prompt | chatmodel | StrOutputParser()

answer = chain.invoke(input)
print(answer)
# Out:
# Communicable diseases remain a major concern for Nigeria’s health system, and the policy context you provided highlights the risk environment in which they occur.
#
# The documents note that Nigeria has recorded progress in some health indicators such as infant and under-five mortality rates, while other areas have shown slow progress or have worsened over the years. The context also flags the interlinked drivers of ill health: *“communicable diseases, food insecurity and poverty, if pro-active action is not taken.”* This points to the need for prevention that goes beyond clinical care to address social determinants.
#
# The policy documents also stress the importance of systems for prevention and response:
# * The National Health Policy is expected to be implemented by federal, state and local governments, with all states and LGAs expected to adapt the policy to their contexts and develop corresponding strategic health development plans for implementation.
# * Monitoring and evaluation of the implementation of the National Health Policy is a defined function, with a Monitoring & Evaluation Framework, Progress Indicators and Data Management and Feedback mechanisms described in the policy.
# * Nigeria developed its national health information policy and strategy in 2014 and has a roadmap to strengthen the health information system across the country. The Federal Ministry of Health has established its national health management information software DHIS2 for routine health information. The documents note fragmentation in data systems due to vertical programmes and parallel systems, and that progress in integrating various versions of the software by disease programmes and partners is slow, with varying reporting rates across the country.
#
# Within that policy and systems context, prevention of communicable diseases in Nigeria is generally pursued through a combination of public health and primary health care actions:
#
# **1. Strengthening surveillance and health information**
# Effective prevention depends on timely, integrated data. Harmonisation of reporting tools, improved compliance with DHIS2 reporting, and integration of disease programme data are needed to detect outbreaks early, target interventions and monitor impact. The policy emphasis on monitoring & evaluation and data management and feedback is central to this.
#
# **2. Immunisation and routine preventive services**
# High coverage of routine immunisation for vaccine-preventable diseases such as measles, polio, yellow fever, tetanus, pneumonia and diarrhoea is a cornerstone of communicable disease prevention. This requires functional primary health care, cold chain maintenance and community demand creation.
#
# **3. Water, sanitation and hygiene WASH**
# Safe water supply, sanitation facilities and hand hygiene reduce transmission of diarrhoeal diseases, cholera, typhoid and other faeco-oral infections. This is particularly important given the link noted in the context between food insecurity, poverty and communicable disease risk.
#
# **4. Vector control and environmental health**
# Control of malaria, dengue, yellow fever and other vector-borne diseases through insecticide-treated nets, indoor residual spraying, larval source management and community clean-up campaigns. Environmental health services at LGA level are key.
#
# **5. Infection prevention and control**
# In health facilities and communities: standard precautions, safe injection practices, proper waste management, and training of health workers to prevent nosocomial transmission.
#
# **6. Health promotion and community engagement**
# Health education on respiratory etiquette, safe food handling, sexual health, and early care-seeking. Community health workers and traditional leaders can support behaviour change and reduce stigma.
#
# **7. Addressing social determinants**
# The context explicitly links communicable diseases with food insecurity and poverty. Prevention therefore requires pro-active action on nutrition, food security, poverty reduction, housing and access to primary health care to reduce vulnerability.
#
# **8. Cross-border and zoonotic disease control**
# Strengthening One Health collaboration for diseases at the human-animal interface, and coordination with neighbouring countries for cross-border outbreaks.
#
# Implementation of these measures is expected under the National Health Policy, with federal, state and local governments adapting the policy to their contexts and developing strategic health development plans. Progress will be tracked through the Monitoring & Evaluation Framework and progress indicators described in the policy.
#
# If you would like, I can map these prevention strategies to specific chapters of the National Health Policy or to the Health Information System roadmap referenced in your documents.

# %% [markdown]
# **Using from messages method**
#
# - Separates **system instructions and user input** into structured messages.
# - Can be adapted for other structured conversations.

# %%
# Define the prompt using from_messages
prompt_messages = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """You are a business consultant providing insights on MSMEs in Nigeria.
            You will be provided with the context: {context} to answer the user's question.
            The context includes sections on understanding, starting, growing, and sustaining MSMEs, policies, and industry-specific information.
            Provide a comprehensive response.
            Include relevant sources or links from the context in your response at the end of each answer, include a statement: "To read more, check out this link: [insert link]."
            Avoid unnecessary or unrelated details. Format the text output clearly and professionally in an HTML format."""
        ),
        ("human", "question: {question}"),
    ]
)

# Prepare the input for the chain
input = {"context": get_doc, "question": question}
# Create the chain
chain = prompt_messages | chatmodel | StrOutputParser()
# Generate and print the answer
result = chain.invoke(input)
print(result)

# %% [markdown]
# ## **Other Retriever Techniques**

# %% [markdown]
# ## Parent Document Retriever
#
#
# When preparing documents for LLMs:
#
# Small chunks improve retrieval quality.
# Large chunks maintain context for better generation.
# Simple strategies like fixed or recursive splitting can't balance both.
#
# **Parent document retrieval solves this by:**
# Embedding small chunks for retrieval.
# Fetching larger chunks or source documents for context.
#
# This ensures the LLM gets complete context, improving response quality. Useful for tasks needing expanded context.

# %% [markdown]
# #### import the necessary libraries
#
# We will require the following libraries for this method:

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain_chroma import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema import Document

# %% [markdown]
# We will be using the Parent Document Retriever library from LangChain.
#
# For this retriever we do **not** want the small chunks we made earlier. We want
# the **full pages** to act as the parent documents, and we let the retriever
# create the small child chunks itself.
#
# So we simply reload the file we want to use.
#
# ** This document consist of two attributes-page_content and metadata.**

# %%
# Reload the sources, but this time keep the documents whole.
# These full pages become the "parent" documents.
pdf_docs = PyPDFLoader("msme_policy.pdf").load()

with open("business_registration_guide.txt", "r", encoding="utf-8") as f:
    txt_text = f.read()

# Wrap the text file into a single document, so both sources match
txt_docs = [Document(page_content=txt_text)]

# Choose the source, the same way we did earlier
chosen_docs = pdf_docs + txt_docs       # use both together
# chosen_docs = pdf_docs                # use only the PDF
# chosen_docs = txt_docs                # use only the text file

msme_documents = [Document(page_content=doc.page_content) for doc in chosen_docs]

print(f"Total Documents to be embedded: {len(msme_documents)}\n")

# %%
#This is to divides the documents into smaller chunks
split_msme = RecursiveCharacterTextSplitter(chunk_size=500)

# %% [markdown]
# Now, let's create a vector store for storing smaller chunks and an InMemoryStore to store the parent documents.
#
# The InMemoryStore functions as a key-value pair data structure, where:
#
# Each key is a unique UUID assigned to a parent document.
#
# Each value is the actual text content of the corresponding parent document.
#
# This structure ensures that while the program is running, the parent documents remain accessible in memory, allowing efficient retrieval and reconstruction of full documents when needed.

# %%
msme_vectorestore = Chroma(collection_name="msme_documents", embedding_function=embeddings)
# This store will retain parent documents for retrieval
store = InMemoryStore()

# %% [markdown]
# Initialize the Parent Document Retriever

# %%
retriever = ParentDocumentRetriever(
    vectorstore = msme_vectorestore , 
    docstore=store, 
    child_splitter=split_msme
)

# %% [markdown]
# Add Documents to Retriever

# %%
retriever.add_documents(msme_documents)

# %% [markdown]
# After adding, we can check how many keys are in the store. Each key is one
# **parent** document - that is, one full PDF page, or the whole text file.
#
# The number below should match the number of documents we printed earlier.

# %%
len(list(store.yield_keys()))

# %% [markdown]
#  This will only returns the small chunks
#
#  Search for relevant document chunks using the vector store

# %%
sub_docs = msme_vectorestore.similarity_search("What is the first step in setting up a business in Nigeria?")
sub_docs

# %% [markdown]
# : Retrieve Relevant Parent Documents

# %%
retrieved_docs = retriever.get_relevant_documents("What is the first step in setting up a business in Nigeria?")

print(retrieved_docs[0].page_content)

# %% [markdown]
# ### Generate Response
#
# we will use the same prompt above

# %%
question = "How long does a business name reservation last in Nigeria?"

#retrieve the document
retrieved_docs = retriever.get_relevant_documents(question)

# Prepare the input for the chain
input = {"context": retrieved_docs, "question": question}

# Create the chain
chain = prompt | chatmodel | StrOutputParser()

answer = chain.invoke(input)
print(answer)

# %% [markdown]
# ### Multiple Query Retriever
#
# This method enhances document retrieval by generating multiple variations of a user query, increasing the likelihood of retrieving relevant documents from a vector database

# %% [markdown]
#  We will prompt the LLM to create five different variations of the user’s query.
# Helps overcome limitations of distance-based similarity search, ensuring that relevant documents aren't missed due to minor phrasing differences.

# %%
template = """You are an AI language model assistant. Your task is to generate five 
different versions of the given user question to retrieve relevant documents from a vector 
database. By generating multiple type of the user question, your goal is to help
the user overcome some of the limitations of the distance-based similarity search. Do not add explanation or numbers to the question, only 
generate the questions.
Provide these alternative questions separated by newlines Original question: {question}"""
multiple_query_prompt = ChatPromptTemplate.from_template(template)

# %% [markdown]
# Alternative versions of the query, which are split into individual questions using split("\n") to create a list.

# %% [markdown]
# Since the LLM generates multiple queries as a block of text with line breaks, we split the text into individual lines to get distinct query variations.
#
# Using .strip() prevents storing empty or whitespace-only strings in the final output.

# %%
# question = "How long does a business name reservation last in Nigeria?"
question ="what is the repayment plan for loan from Development Bank of Nigeria"

multiple_queries = multiple_query_prompt | chatmodel | StrOutputParser() | (lambda x: [q for q in x.split("\n") if q.strip()])
multiple_answer = multiple_queries.invoke({"question" : question})
print(multiple_answer)

# %% [markdown]
# Define the Retriever

# %%
msme_retriever = msmevdb.as_retriever()

# %% [markdown]
# Get Unique Documents
#
#
# Let us Convert the documents into JSON strings using dumps() and also remove duplicates using (set), and convert them back to objects using loads().
#
# This is to ensure the retrieved documents are unique.

# %%
from langchain.load import dumps, loads
def unique_doc (documents): 
    unique_doc = list(set(dumps(doc)for doc in documents))
    return [loads(doc) for doc in unique_doc]

# %% [markdown]
# Retrieving Documents Using Multiple Queries
#
# With .map(), The msme_retriever processes each query separately, retrieving relevant documents for each one instead of handling all queries at once.

# %%
retrieval_chain = multiple_queries | msme_retriever.map() | unique_doc

# %% [markdown]
# Answer Generation Using Retrieved Documents
#
#  We pass all the retrieved documents as context along with the original question to the llm

# %%
prompt = ChatPromptTemplate.from_template(
    """You are a business consultant providing insights on MSMEs in Nigeria.
You will be provided with the context: {context} to answer the user's question.
The context includes sections on understanding, starting, growing, and sustaining MSMEs, policies, and industry-specific information.
Provide a detailed and comprehensive response.
Include relevant sources or links from the context in your response. At the end of each answer, include a statement: "To read more, check out this link: [insert link]."
Avoid unnecessary or unrelated details. Format the text output clearly and professionally in an HTML format in not more than 5 sentences.
question: {question}""")

multiple_query_input = ({"context" : retrieval_chain, "question": question})

chain = prompt| chatmodel| StrOutputParser()

answer = chain.invoke(multiple_query_input)
print(answer)

# %% [markdown]
# ### BM25 (BEST MATCHING 25)

# %% [markdown]
# **Problem:** Dense models sometimes overlook exact keywords in queries.
# **Solution:** Uses term frequency (TF-IDF) to rank documents with strong keyword overlap.
#
# - Great for domains with specific terms (e.g., law, code)
# - Useful for hybrid retrieval (dense + sparse)
# - Fast and interpretable baseline

# %% [markdown]
#  Imports and Setup the neccessary libraries

# %%
from langchain.retrievers import EnsembleRetriever
from langchain_community.retrievers import BM25Retriever
from langchain.schema import Document
from nltk.tokenize import word_tokenize
import nltk

# Downloads tokenization rules
nltk.download("punkt_tab")

# %% [markdown]
# **Load the Vector Store (Semantic Retriever)**

# %%
msmevdb = Chroma(
    collection_name="msme",
    embedding_function=embeddings,
    persist_directory=chroma_path
)

# %% [markdown]
# ** Extract Raw Documents and Convert to LangChain Format**
#
# You're fetching all the stored text back out of Chroma.
#
# Then wrapping them as LangChain Document objects so they can be passed to other retrievers (like BM25).

# %%
question_docs = msmevdb.get(include=['documents'])
question_documents = [Document(page_content=doc) for doc in question_docs['documents']]

print("Documents pulled back out of Chroma:", len(question_documents))

# %% [markdown]
# **Create Two Individual Retrievers**

# %%
question_semantic = msmevdb.as_retriever()
question_bm25 = BM25Retriever.from_documents(question_documents, preprocess_func=word_tokenize)

# %% [markdown]
# **Combine Both with EnsembleRetriever**
#
# Combines both retrievers.
#
# The weights=[0.5, 0.5] means equal influence from semantic and keyword-based scores.
#
# You can adjust the weights to favor one over the other.

# %%
bm25_retriever = EnsembleRetriever(retrievers=[question_semantic, question_bm25], weights=[0.5, 0.5])

# %%
question = "How do i register a construction business Nigeria"
results = bm25_retriever.get_relevant_documents(question )
results

# %%
# Prepare the input for the chain
input = {"context": results , "question": question}

# Create the chain
chain = prompt | chatmodel | StrOutputParser()

answer = chain.invoke(input)
print(answer)

# %% [markdown]
# ### RAG EVALUATION TECHNIQUES

# %% [markdown]
# #### RAG Evaluation using RAGAS
#
# Retrieval-Augmented Generation (RAG) systems should not just “sound correct” — they must retrieve accurate, relevant, and faithful content.
#
# We use RAGAS (Retrieval-Augmented Generation Assessment Suite) to measure how well the system performs on both retrieval and generation steps.

# %%
from langchain_openai import ChatOpenAI

# %% [markdown]
# **Sample Queries and References (Ground Truth)**
#
# These represent typical user questions and what the system should ideally answer.
#
# They form the evaluation dataset.

# %%
sample_queries = [
    "What are the classification criteria for MSMEs in Nigeria according to the National Policy on MSMEs?",
    "How do SMEDAN, BoI, and CBN define micro, small, and medium enterprises differently?",
    "What are the key challenges faced by MSMEs in Nigeria?",
    "Which sectors dominate micro enterprises in Nigeria, and what percentage do they represent?",
    "What government interventions or policies have been introduced to support MSMEs in Nigeria?"
]

expected_responses = [
    "The National Policy on MSMEs classifies enterprises as: Micro (<10 employees, assets <₦10M), Small (10-49 employees, assets ₦10M-₦100M), and Medium (50-199 employees, assets ₦100M-₦1B). Employment criteria take precedence if conflicts arise with asset thresholds.",
    "SMEDAN defines Micro (<10 employees, <₦5M assets), Small (10-49 employees, ₦5M-₦50M assets), and Medium (50-199 employees, ₦50M-₦500M assets). BoI and CBN use similar employee ranges but differ slightly in turnover/asset thresholds (e.g., BoI includes turnover <₦20M for Micro).",
    "Key challenges include poor access to credit, low market access, weak infrastructure, discriminatory legislation, and lack of technical skills. Micro enterprises also face funding constraints (reliance on personal savings/community funds).",
    "Micro enterprises are dominated by wholesale/retail trade (54.67%), followed by manufacturing (13.21%), agriculture (8.92%), and services (7.80%). The 2013 survey estimated 36.99 million micro enterprises in Nigeria.",
    "Interventions include SMEDAN (capacity building), BOI/CBN loan schemes, the Finance Act 2019/2020 (tax exemptions for small businesses), and programs like the National Economic Reconstruction Fund. Historical schemes date back to the 1970s (e.g., Agricultural Credit Guarantee Scheme)."
]

# %% [markdown]
# **Evaluate a Specific Retriever (e.g. BM25)**

# %%
#Let us evaluate one of our retriever. lets evaluate the BM25

relevant_docs=bm25_retriever.get_relevant_documents(question )

# %% [markdown]
# #### Run the Generation Chain
#
# This chain creates the final LLM answer based on the retrieved context and the query.

# %%
# Prepare the input for the chain
input = {"context":  relevant_docs , "question": question}

# Create the chain
chain = prompt | chatmodel | StrOutputParser()

# %% [markdown]
# #### Build the Evaluation Dataset
#
# For each query:
#
# You retrieve documents
#
# Run the LLM chain
#
# Store the question, context, model answer, and reference answer in a list

# %%
dataset = []

for query, reference in zip(sample_queries, expected_responses):
    # Get relevant documents
    relevant_docs = bm25_retriever.get_relevant_documents(query)
    
    # Convert Document objects to strings for the context
    retrieved_contexts = [doc.page_content for doc in relevant_docs]
    
    # Get the model's response
    response = chain.invoke({"question": query, "context": retrieved_contexts})  # Adjust if your chain expects different input
    
    dataset.append({
        "user_input": query,        # Required by context_recall
        "contexts": retrieved_contexts,  # Used by context precision/relevancy
        "retrieved_contexts": retrieved_contexts,  # Required by context_recall
        "response": response,         # The generated answer
        "reference": reference     # Required by context_recall
    })

# %% [markdown]
# **Now, load the dataset into EvaluationDataset object.**

# %%
from ragas import EvaluationDataset

evaluation_dataset = EvaluationDataset.from_list(dataset)

# %% [markdown]
# #### Set Up the LLM Evaluator

# %%
from ragas import evaluate
from ragas.llms import LangchainLLMWrapper

llm = ChatOpenAI(
    api_key=api_key,
    base_url=base_url,
    model=chat_model_name,
    temperature=0
)
evaluator_llm = LangchainLLMWrapper(llm)

# %%
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness,  ResponseRelevancy

# %% [markdown]
# #### Choose RAGAS Metrics
#
# LLMContextRecall: Measures if enough relevant info was retrieved
#
# Faithfulness: Checks if the answer sticks to the retrieved info (no hallucinations)
#
# FactualCorrectness: Verifies if the answer is factually accurate compared to the

# %% [markdown]
# ##### Run Evaluation

# %%
result = evaluate(dataset=evaluation_dataset,metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness()],llm=evaluator_llm)
result

# %% [markdown]
# **Result of our evaluation metrics**
#
# Context Recall (0.90): The retriever is doing very well — it returns most of the relevant documents.
#
# Faithfulness (0.98): The LLM sticks closely to the retrieved context — very low hallucination.
#
#  Factual Correctness (0.59): Many answers miss details or don’t fully match the reference — accuracy needs improvement.
