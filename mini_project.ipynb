# %% [markdown]
#    # MINI PROJECT
# ### A Simple Python Identity Card

# %%
print("=" * 40)
print("Python Learner Identity Card")
print("=" *40)


full_name = input("your full name:")
age = input("your age:")
country = input("your country:")
area_of_focus = input("your area of focus:")
goal = input("your learning goal:")

print("Full name:" , full_name)
print("Age:", age)
print("Country:", country)
print("Area of focus:", area_of_focus)
print("Goal:", goal)
print("=" * 40)
print("You can do it" + "." )
print("=" *40)
# Out:
# Running cells with 'myvenv (3.14.7.final.0) (Python 3.14.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/USER/OneDrive/Desktop/python-intro/myvenv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
